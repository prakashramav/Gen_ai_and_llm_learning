# %%
from langchain_community.document_loaders import UnstructuredURLLoader
urls = ['https://www.victoriaonmove.com.au/local-removalists.html','https://victoriaonmove.com.au/index.html','https://victoriaonmove.com.au/contact.html']
loader = UnstructuredURLLoader(urls=urls)
data = loader.load()
# Out:
# C:\Users\arjun\AppData\Local\Temp\ipykernel_34844\198583204.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import UnstructuredURLLoader

# %%
data
# Out:
# [Document(metadata={'source': 'https://www.victoriaonmove.com.au/local-removalists.html'}, page_content="Local Removalists Melbourne\n\nTop-notch local moving services tailored to your needs — from studio apartments to large family homes.\n\nWhat We Do\n\nComprehensive Local Moving Services\n\nWe offer a full range of local moving services for Melbourne residents and businesses. Our experienced team handles every move with care and professionalism.\n\nApartment Moving\n\nEfficient and careful relocation services tailored for apartments of all sizes. We navigate lifts, stairs, and narrow corridors with ease.\n\nVilla Moving\n\nComprehensive moving solutions for large residences and villas. We handle your valuable possessions with the utmost care and attention.\n\nHousehold Moving\n\nFull-service moving options for households of every size, including packing, loading, transportation, and unpacking at your new home.\n\nOffice Moving\n\nSpecialised expertise in office relocations. We minimise downtime and ensure your business is up and running as quickly as possible.\n\nFurniture Moving\n\nExperienced in handling furniture of all sizes and types. We use trolleys, blankets, and straps to protect every piece during transit.\n\nPacking & Unpacking\n\nOptional packing and unpacking services available to save you time and effort. We use quality materials to ensure safe transit of all items.\n\nCustomised Plans\n\nNot every move is the same. We offer tailored moving plans to fit your specific requirements, schedule, and budget.\n\nInsured & Protected\n\nEvery move includes transit and public liability insurance. Your goods are fully protected from loading through to delivery at your new home.\n\nOur Fleet\n\nRight Truck for Every Move\n\nAll trucks include 2 professional movers, trolleys, moving blankets, and loading ramps.\n\nSmall Truck\n\n$125/hr\n\nWith 2 Movers\n\n4.5 ton · 20 m³\n\nStudent apartments and small 1-bedroom homes.\n\nMedium Truck\n\n$140/hr\n\nWith 2 Movers\n\n6 ton · 30–35 m³\n\n2–3 bedroom homes with lounge and outdoor items.\n\nLarge Truck\n\n$150/hr\n\nWith 2 Movers\n\n8 ton · 40 m³\n\n3–4 bedroom homes with double lounge.\n\nX-Large Truck\n\n$160/hr\n\nWith 2 Movers\n\n10 ton · 50 m³\n\nLarge multi-bedroom properties with all extra items.\n\n12-Ton Truck\n\n$180/hr\n\nWith 2 Movers\n\n12 ton · 65 m³\n\nOur largest truck — 5+ bedroom homes, full office relocations, heavy loads.\n\nReady to Move? Get a Free Quote Today!\n\nContact us now for a quick quote. We'll help you choose the right truck and plan for a stress-free move.\n\nGet a Free Quote Call 0404 922 328\n\nCall Us\n\n0404 922 328\n\nEmail Us\n\nvictoriaonmove07@gmail.com\n\nLocation\n\nWollert, Victoria\n\nVictoria On Move\n\nYour trusted partner in seamless moving and packing solutions. Serving Melbourne and all of Australia with professionalism and care.\n\n© Victoria On Move 2024. All Rights Reserved.\n\nWollert, Victoria · 0404 922 328"),
#  Document(metadata={'source': 'https://victoriaonmove.com.au/index.html'}, page_content='★★★★★ 5.0 · 111 Google Reviews\n\nRelocate with Confidence\n\nYour trusted partner in seamless moving and packing solutions — serving Melbourne and all of Australia.\n\nGet a Free Quote Call 0404 922 328\n\n5.0★\n\nGoogle Rating\n\n111\n\nVerified Reviews\n\nInterstate Routes\n\n$125\n\nStarting /hr\n\nVictoria On Move team carefully wrapping furniture for a move\n\nMoving boxes neatly stacked inside a Victoria On Move truck\n\nVictoria On Move removalists carefully moving large furniture items\n\nOur Fleet\n\nTransparent, Affordable Pricing\n\nAll trucks come with 2 experienced movers, trolleys, blankets, and loading ramps. No hidden fees.\n\nVictoria On Move small truck — 4.5 ton, ideal for 1-bedroom moves\n\nMost Popular\n\nSmall Truck\n\n$125/hr\n\nWith 2 Movers\n\n4.5 ton · 20 m³\n\nIdeal for student apartments, small offices, and 1-bedroom homes.\n\nBook This Truck →\n\nVictoria On Move medium truck — 6 ton, ideal for 2-3 bedroom homes\n\nMedium Truck\n\n$140/hr\n\nWith 2 Movers\n\n6 ton · 30–35 m³\n\nHandles 2–3 bedroom homes with single lounge, outdoor boxes, and miscellaneous items.\n\nBook This Truck →\n\nVictoria On Move large truck — 8 ton, ideal for 3-4 bedroom homes\n\nLarge Truck\n\n$150/hr\n\nWith 2 Movers\n\n8 ton · 40 m³\n\nPerfect for 3–4 bedroom homes with double lounge, outdoor boxes, and miscellaneous items.\n\nBook This Truck →\n\nVictoria On Move X-large truck — 10 ton, ideal for large homes\n\nX-Large Truck\n\n$160/hr\n\nWith 2 Movers\n\n10 ton · 50 m³\n\nManages large 3–4 bedroom homes with double lounge and all extra items.\n\nBook This Truck →\n\nVictoria On Move 12-ton truck — largest fleet truck, ideal for big 5+ bedroom homes\n\nBiggest Truck\n\n12-Ton Truck\n\n$180/hr\n\nWith 2 Movers\n\n12 ton · 65 m³\n\nOur largest truck for 5+ bedroom homes, full office relocations, and heavy interstate loads.\n\nBook This Truck →\n\nWhat We Offer\n\nQuick & Powerful Logistics Solutions\n\nFrom packing to unpacking, our experienced teams handle every aspect of your move with care.\n\nFurniture Removals\n\nWe are furniture removal specialists in Victoria. Our teams come equipped with trolleys, blankets, and loading ramps to protect your belongings.\n\nFully Insured\n\nVictoria On Move includes transit and public liability insurance with every move. Coverage applies during loading, unloading, and road transport.\n\nProfessional Team\n\nExperienced, courteous movers dedicated to exceptional service. We treat your belongings with the same care we\'d give our own.\n\nPacking Services\n\nOptional packing and unpacking services using quality materials to ensure your items arrive safely at their destination.\n\nHome Removals\n\nFull-service home moving from 1-bedroom apartments to large 5-bedroom properties. We tailor every move to your specific needs.\n\nInterstate Moves\n\nReliable interstate removalist services from Melbourne to Sydney, Brisbane, Adelaide, and Canberra with transparent pricing.\n\nHome Packages\n\nMoving Packages by Home Size\n\nChoose the package that best fits your home. Not sure? Call us and we\'ll help you decide.\n\n1 Bedroom Home\n\nSmall Truck from $125/hr\n\n1 Bed & Mattress\n\nTall Boy\n\nBedside Table\n\nRefrigerator\n\nWashing Machine\n\nSome Boxes\n\n2 Bedroom Home\n\nMedium Truck from $140/hr\n\n2 Beds & Mattresses\n\nTall Boy & Bedside Tables\n\nRefrigerator\n\nWashing Machine\n\nDresser\n\nBarbeque\n\nBoxes & Loose Stuff\n\nLarge Home (4–5 Bed)\n\nLarge or X-Large Truck\n\n4–5 Bedrooms\n\nDouble Lounge\n\nAll Beds & Mattresses\n\nTall Boy & Bedside Tables\n\nRefrigerator & Washing Machine\n\nDresser & Barbeque\n\nFurniture, Boxes & Loose Stuff\n\nOur Work\n\nSee Us in Action\n\nReal moves, real customers, real results. Browse our gallery to see the quality and care we bring to every job.\n\nVictoria On Move team wrapping furniture for a move\n\nVictoria On Move truck on a Melbourne removal job\n ...
#  Document(metadata={'source': 'https://victoriaonmove.com.au/contact.html'}, page_content="Contact Us & Get a Free Quote\n\nFill in the form below or call us directly — we'll get back to you quickly with a personalised moving quote.\n\nGet in Touch\n\nContact Information\n\nWe're available 24/7 via email and phone. Drop us a message or call us to discuss your move.\n\nPhone\n\n0404 922 328\n\nEmail\n\nvictoriaonmove07@gmail.com\n\nLocation\n\nWollert, Victoria, Australia\n\nAvailability\n\nAvailable 24/7 via email and phone\n\nWe accept:\n\nCash Bank Transfer Visa Mastercard\n\nRequest a Moving Quote\n\nFill in the details below and we'll provide you with a personalised quote as soon as possible.\n\nVictoria On Move\n\nYour trusted partner in seamless moving and packing solutions. Serving Melbourne and all of Australia with professionalism and care.\n\n© Victoria On Move 2024. All Rights Reserved.\n\nWollert, Victoria · 0404 922 328")]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# split data
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000)
docs = text_splitter.split_documents(data)


print("Total number of documents: ",len(docs))

docs
# Out:
# Total number of documents:  16
# [Document(metadata={'source': 'https://www.victoriaonmove.com.au/local-removalists.html'}, page_content='Local Removalists Melbourne\n\nTop-notch local moving services tailored to your needs — from studio apartments to large family homes.\n\nWhat We Do\n\nComprehensive Local Moving Services\n\nWe offer a full range of local moving services for Melbourne residents and businesses. Our experienced team handles every move with care and professionalism.\n\nApartment Moving\n\nEfficient and careful relocation services tailored for apartments of all sizes. We navigate lifts, stairs, and narrow corridors with ease.\n\nVilla Moving\n\nComprehensive moving solutions for large residences and villas. We handle your valuable possessions with the utmost care and attention.\n\nHousehold Moving\n\nFull-service moving options for households of every size, including packing, loading, transportation, and unpacking at your new home.\n\nOffice Moving\n\nSpecialised expertise in office relocations. We minimise downtime and ensure your business is up and running as quickly as possible.\n\nFurniture Moving'),
#  Document(metadata={'source': 'https://www.victoriaonmove.com.au/local-removalists.html'}, page_content='Office Moving\n\nSpecialised expertise in office relocations. We minimise downtime and ensure your business is up and running as quickly as possible.\n\nFurniture Moving\n\nExperienced in handling furniture of all sizes and types. We use trolleys, blankets, and straps to protect every piece during transit.\n\nPacking & Unpacking\n\nOptional packing and unpacking services available to save you time and effort. We use quality materials to ensure safe transit of all items.\n\nCustomised Plans\n\nNot every move is the same. We offer tailored moving plans to fit your specific requirements, schedule, and budget.\n\nInsured & Protected\n\nEvery move includes transit and public liability insurance. Your goods are fully protected from loading through to delivery at your new home.\n\nOur Fleet\n\nRight Truck for Every Move\n\nAll trucks include 2 professional movers, trolleys, moving blankets, and loading ramps.\n\nSmall Truck\n\n$125/hr\n\nWith 2 Movers\n\n4.5 ton · 20 m³\n\nStudent apartments and small 1-bedroom homes.'),
#  Document(metadata={'source': 'https://www.victoriaonmove.com.au/local-removalists.html'}, page_content="All trucks include 2 professional movers, trolleys, moving blankets, and loading ramps.\n\nSmall Truck\n\n$125/hr\n\nWith 2 Movers\n\n4.5 ton · 20 m³\n\nStudent apartments and small 1-bedroom homes.\n\nMedium Truck\n\n$140/hr\n\nWith 2 Movers\n\n6 ton · 30–35 m³\n\n2–3 bedroom homes with lounge and outdoor items.\n\nLarge Truck\n\n$150/hr\n\nWith 2 Movers\n\n8 ton · 40 m³\n\n3–4 bedroom homes with double lounge.\n\nX-Large Truck\n\n$160/hr\n\nWith 2 Movers\n\n10 ton · 50 m³\n\nLarge multi-bedroom properties with all extra items.\n\n12-Ton Truck\n\n$180/hr\n\nWith 2 Movers\n\n12 ton · 65 m³\n\nOur largest truck — 5+ bedroom homes, full office relocations, heavy loads.\n\nReady to Move? Get a Free Quote Today!\n\nContact us now for a quick quote. We'll help you choose the right truck and plan for a stress-free move.\n\nGet a Free Quote Call 0404 922 328\n\nCall Us\n\n0404 922 328\n\nEmail Us\n\nvictoriaonmove07@gmail.com\n\nLocation\n\nWollert, Victoria\n\nVictoria On Move"),
#  Document(metadata={'source': 'https://www.victoriaonmove.com.au/local-removalists.html'}, page_content='Get a Free Quote Call 0404 922 328\n\nCall Us\n\n0404 922 328\n\nEmail Us\n\nvictoriaonmove07@gmail.com\n\nLocation\n\nWollert, Victoria\n\nVictoria On Move\n\nYour trusted partner in seamless moving and packing solutions. Serving Melbourne and all of Australia with professionalism and care.\n\n© Victoria On Move 2024. All Rights Reserved.\n\nWollert, Victoria · 0404 922 328'),
#  Document(metadata={'source': 'https://victoriaonmove.com.au/index.html'}, page_content='★★★★★ 5.0 · 111 Google Reviews\n\nRelocate with Confidence\n\nYour trusted partner in seamless moving and packing solutions — serving Melbourne and all of Australia.\n\nGet a Free Quote Call 0404 922 328\n\n5.0★\n\nGoogle Rating\n\n111\n\nVerified Reviews\n\nInterstate Routes\n\n$125\n\nStarting /hr\n\nVictoria On Move team carefully wrapping furniture for a move\n\nMoving boxes neatly stacked inside a Victoria On Move truck\n\nVictoria On Move removalists carefully moving large furniture items\n\nOur Fleet\n\nTransparent, Affordable Pricing\n\nAll trucks come with 2 experienced movers, trolleys, blankets, and loading ramps. No hidden fees.\n\nVictoria On Move small truck — 4.5 ton, ideal for 1-bedroom moves\n\nMost Popular\n\nSmall Truck\n\n$125/hr\n\nWith 2 Movers\n\n4.5 ton · 20 m³\n\nIdeal for student apartments, small offices, and 1-bedroom homes.\n\nBook This Truck →\n\nVictoria On Move medium truck — 6 ton, ideal for 2-3 bedroom homes\n\nMedium Truck\n\n$140/hr\n\nWith 2 Movers\n\n6 ton · 30–35 m³'),
#  Document(metadata={'source': 'https://victoriaonmove.com.au/index.html'}, page_content='Book This Truck →\n\nVictoria On Move medium truck — 6 ton, ideal for 2-3 bedroom homes\n\nMedium Truck\n\n$140/hr\n\nWith 2 Movers\n\n6 ton · 30–35 m³\n\nHandles 2–3 bedroom homes with single lounge, outdoor boxes, and miscellaneous items.\n\nBook This Truck →\n\nVictoria On Move large truck — 8 ton, ideal for 3-4 bedroom homes\n\nLarge Truck\n\n$150/hr\n\nWith 2 Movers\n\n8 ton · 40 m³\n\nPerfect for 3–4 bedroom homes with double lounge, outdoor boxes, and miscellaneous items.\n\nBook This Truck →\n\nVictoria On Move X-large truck — 10 ton, ideal for large homes\n\nX-Large Truck\n\n$160/hr\n\nWith 2 Movers\n\n10 ton · 50 m³\n\nManages large 3–4 bedroom homes with double lounge and all extra items.\n\nBook This Truck →\n\nVictoria On Move 12-ton truck — largest fleet truck, ideal for big 5+ bedroom homes\n\nBiggest Truck\n\n12-Ton Truck\n\n$180/hr\n\nWith 2 Movers\n\n12 ton · 65 m³\n\nOur largest truck for 5+ bedroom homes, full office relocations, and heavy interstate loads.\n\nBook This Truck →\n\nWhat We Offer'),
#  Document(metadata={'source': 'https://victoriaonmove.com.au/index.html'}, page_content="Biggest Truck\n\n12-Ton Truck\n\n$180/hr\n\nWith 2 Movers\n\n12 ton · 65 m³\n\nOur largest truck for 5+ bedroom homes, full office relocations, and heavy interstate loads.\n\nBook This Truck →\n\nWhat We Offer\n\nQuick & Powerful Logistics Solutions\n\nFrom packing to unpacking, our experienced teams handle every aspect of your move with care.\n\nFurniture Removals\n\nWe are furniture removal specialists in Victoria. Our teams come equipped with trolleys, blankets, and loading ramps to protect your belongings.\n\nFully Insured\n\nVictoria On Move includes transit and public liability insurance with every move. Coverage applies during loading, unloading, and road transport.\n\nProfessional Team\n\nExperienced, courteous movers dedicated to exceptional service. We treat your belongings with the same care we'd give our own.\n\nPacking Services\n\nOptional packing and unpacking services using quality materials to ensure your items arrive safely at their destination.\n\nHome Removals"),
#  Document(metadata={'source': 'https://victoriaonmove.com.au/index.html'}, page_content="Packing Services\n\nOptional packing and unpacking services using quality materials to ensure your items arrive safely at their destination.\n\nHome Removals\n\nFull-service home moving from 1-bedroom apartments to large 5-bedroom properties. We tailor every move to your specific needs.\n\nInterstate Moves\n\nReliable interstate removalist services from Melbourne to Sydney, Brisbane, Adelaide, and Canberra with transparent pricing.\n\nHome Packages\n\nMoving Packages by Home Size\n\nChoose the package that best fits your home. Not sure? Call us and we'll help you decide.\n\n1 Bedroom Home\n\nSmall Truck from $125/hr\n\n1 Bed & Mattress\n\nTall Boy\n\nBedside Table\n\nRefrigerator\n\nWashing Machine\n\nSome Boxes\n\n2 Bedroom Home\n\nMedium Truck from $140/hr\n\n2 Beds & Mattresses\n\nTall Boy & Bedside Tables\n\nRefrigerator\n\nWashing Machine\n\nDresser\n\nBarbeque\n\nBoxes & Loose Stuff\n\nLarge Home (4–5 Bed)\n\nLarge or X-Large Truck\n\n4–5 Bedrooms\n\nDouble Lounge\n\nAll Beds & Mattresses\n\nTall Boy & Bedside Tables"),
#  Document(metadata={'source': 'https://victoriaonmove.com.au/index.html'}, page_content='Refrigerator\n\nWashing Machine\n\nDresser\n\nBarbeque\n\nBoxes & Loose Stuff\n\nLarge Home (4–5 Bed)\n\nLarge or X-Large Truck\n\n4–5 Bedrooms\n\nDouble Lounge\n\nAll Beds & Mattresses\n\nTall Boy & Bedside Tables\n\nRefrigerator & Washing Machine\n\nDresser & Barbeque\n\nFurniture, Boxes & Loose Stuff\n\nOur Work\n\nSee Us in Action\n\nReal moves, real customers, real results. Browse our gallery to see the quality and care we bring to every job.\n\nVictoria On Move team wrapping furniture for a move\n\nVictoria On Move truck on a Melbourne removal job\n\nVictoria On Move removalists carefully moving a large item\n\nMoving boxes neatly stacked inside a Victoria On Move truck\n\nView Full Gallery\n\nInterstate Services\n\nMelbourne Interstate Removalists\n\nWe move you safely from Melbourne to any major Australian city — professional, reliable, and on time.\n\nGoogle Maps route Melbourne to Sydney\n\n878 km · ~9 hrs\n\nMelbourne\n\n→ Sydney'),
#  Document(metadata={'source': 'https://victoriaonmove.com.au/index.html'}, page_content='We move you safely from Melbourne to any major Australian city — professional, reliable, and on time.\n\nGoogle Maps route Melbourne to Sydney\n\n878 km · ~9 hrs\n\nMelbourne\n\n→ Sydney\n\nExpert packing, secure transport, and professional unpacking. Fast and reliable interstate service.\n\nBook Now →\n\nGoogle Maps route Melbourne to Brisbane\n\n1,682 km · ~17 hrs\n\nMelbourne\n\n→ Brisbane\n\nComprehensive Brisbane removals with transparent pricing and no hidden fees.\n\nBook Now →\n\nGoogle Maps route Melbourne to Adelaide\n\n727 km · ~7 hrs\n\nMelbourne\n\n→ Adelaide\n\nStress-free Adelaide interstate moves with quality materials and full insurance coverage.\n\nBook Now →\n\nGoogle Maps route Melbourne to Canberra\n\n653 km · ~7 hrs\n\nMelbourne\n\n→ Canberra\n\nProfessional Canberra removalists with flexible scheduling and customer-focused service.\n\nBook Now →\n\nMap of Melbourne to Cairns interstate removalist route\n\n2,878 km · ~29 hrs\n\nMelbourne\n\n→ Cairns'),
#  Document(metadata={'source': 'https://victoriaonmove.com.au/index.html'}, page_content="Professional Canberra removalists with flexible scheduling and customer-focused service.\n\nBook Now →\n\nMap of Melbourne to Cairns interstate removalist route\n\n2,878 km · ~29 hrs\n\nMelbourne\n\n→ Cairns\n\nLong-haul Cairns interstate removals handled with care, full insurance, and reliable delivery.\n\nBook Now →\n\nReal Moves. Real Team.\n\nWatch Us in Action\n\nNo actors, no stock footage — just our crew doing what we do best, every single day.\n\nMoving Day\n\nWrapping & Packing\n\nLoading Up\n\nOn the Road\n\nDelivery\n\nHappy Clients\n\nFurniture Care\n\nTeam at Work\n\nInterstate Run\n\nHover or tap any video to play · All footage is real — our team, our trucks, our work\n\nOur Commitment\n\nOur Moving Work & Ethics\n\nMoving house furniture is an art that comes with experience and a steadfast commitment to our customers' needs. At Victoria On Move, we approach every relocation with the same dedication — whether it's a single bedroom apartment or a large family home."),
#  Document(metadata={'source': 'https://victoriaonmove.com.au/index.html'}, page_content="Unlike some other moving companies, we value the trust our customers place in us. Our customer reviews on Google are genuine, and we never manipulate them. Every 5-star review is earned through hard work and exceptional service.\n\nFully Insured\n\nTransit and public liability insurance on every move. Your goods are protected from loading to delivery.\n\nGenuine 5-Star Reviews\n\n111 authentic Google reviews — never manipulated. Our reputation is built on real customer experiences.\n\nTransparent Pricing\n\nHourly rates with no hidden fees. What you're quoted is what you pay — simple and straightforward.\n\n5.0★\n\nGoogle Rating\n\n111\n\nVerified Reviews\n\nInterstate Routes\n\n24/7\n\nAvailable via Email\n\nGet a Free Quote\n\nClient Reviews\n\nOur Clients Say!\n\nDiscover firsthand experiences from our valued clients. From seamless moves to exceptional service, our customers share how we made their relocation stress-free and rewarding.\n\n★★★★★"),
#  Document(metadata={'source': 'https://victoriaonmove.com.au/index.html'}, page_content='Discover firsthand experiences from our valued clients. From seamless moves to exceptional service, our customers share how we made their relocation stress-free and rewarding.\n\n★★★★★\n\n"Absolutely fantastic service! The team was punctual, professional, and handled all our furniture with great care. Highly recommend Victoria On Move!"\n\nReviewer photo\n\nSarah M.\n\nMelbourne, VIC\n\n★★★★★\n\n"We moved from Melbourne to Sydney and the entire process was seamless. Competitive pricing, no hidden fees, and the crew was amazing."\n\nReviewer photo\n\nJames T.\n\nSydney, NSW\n\n★★★★★\n\n"Very professional and efficient. They packed everything carefully and delivered on time. Will definitely use again for our next move."\n\nReviewer photo\n\nPriya K.\n\nWollert, VIC\n\n★★★★★\n\n"Outstanding removalists! They helped us move a large 4-bedroom home without any stress. The X-Large truck was perfect for all our belongings."\n\nReviewer photo\n\nDavid L.\n\nCraigieburn, VIC\n\n★★★★★'),
#  Document(metadata={'source': 'https://victoriaonmove.com.au/index.html'}, page_content='"Outstanding removalists! They helped us move a large 4-bedroom home without any stress. The X-Large truck was perfect for all our belongings."\n\nReviewer photo\n\nDavid L.\n\nCraigieburn, VIC\n\n★★★★★\n\n"Used Victoria On Move for our office relocation. Minimal downtime, very organised, and the team were careful with all our equipment. 10/10!"\n\nReviewer photo\n\nEmily R.\n\nEpping, VIC\n\n★★★★★\n\n"Great value for money. The movers were friendly and worked really hard. Nothing was damaged and they finished ahead of schedule."\n\nReviewer photo\n\nMohammed A.\n\nSouth Morang, VIC\n\n★★★★★\n\n"Interstate move from Melbourne to Brisbane was handled perfectly. Good communication throughout and the delivery was on time. Very happy!"\n\nReviewer photo\n\nLisa W.\n\nBrisbane, QLD\n\n★★★★★\n\n"Trustworthy, efficient, and affordable. The team took extra care with our antique furniture and piano. Would not use any other removalist."\n\nReviewer photo\n\nChen F.\n\nDoreen, VIC\n\n★★★★★'),
#  Document(metadata={'source': 'https://victoriaonmove.com.au/index.html'}, page_content='★★★★★\n\n"Trustworthy, efficient, and affordable. The team took extra care with our antique furniture and piano. Would not use any other removalist."\n\nReviewer photo\n\nChen F.\n\nDoreen, VIC\n\n★★★★★\n\n"Moving with kids and pets is stressful but these guys made it so easy. Quick, careful, and very reasonably priced. Highly recommend!"\n\nReviewer photo\n\nAmelia S.\n\nMernda, VIC\n\n★★★★★\n\n"Second time using Victoria On Move. As good as the first time — maybe even better. They really care about doing a good job. 5 stars every time!"\n\nReviewer photo\n\nRyan B.\n\nWhittlesea, VIC\n\nCall Us\n\n0404 922 328\n\nEmail Us\n\nvictoriaonmove07@gmail.com\n\nLocation\n\nWollert, Victoria\n\nVictoria On Move\n\nYour trusted partner in seamless moving and packing solutions. Serving Melbourne and all of Australia with professionalism and care since 2024.\n\n© Victoria On Move 2024. All Rights Reserved.\n\nWollert, Victoria · 0404 922 328\n\nCheck us out on Google!\n\nGoogle Reviews ★★★★★ 5.0'),
#  Document(metadata={'source': 'https://victoriaonmove.com.au/contact.html'}, page_content="Contact Us & Get a Free Quote\n\nFill in the form below or call us directly — we'll get back to you quickly with a personalised moving quote.\n\nGet in Touch\n\nContact Information\n\nWe're available 24/7 via email and phone. Drop us a message or call us to discuss your move.\n\nPhone\n\n0404 922 328\n\nEmail\n\nvictoriaonmove07@gmail.com\n\nLocation\n\nWollert, Victoria, Australia\n\nAvailability\n\nAvailable 24/7 via email and phone\n\nWe accept:\n\nCash Bank Transfer Visa Mastercard\n\nRequest a Moving Quote\n\nFill in the details below and we'll provide you with a personalised quote as soon as possible.\n\nVictoria On Move\n\nYour trusted partner in seamless moving and packing solutions. Serving Melbourne and all of Australia with professionalism and care.\n\n© Victoria On Move 2024. All Rights Reserved.\n\nWollert, Victoria · 0404 922 328")]

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore = Chroma.from_documents(
    documents=docs,
    embedding=embeddings
)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# c:\Users\arjun\Desktop\GenAI and LLM\rag_demo\venv\Lib\site-packages\huggingface_hub\file_download.py:142: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\arjun\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 6})

retrieved_docs = retriever.invoke("What kind of services they provide?")

# %%
len(retrieved_docs)
# Out:
# 6

# %%
print(retrieved_docs[0].page_content)
# Out:
# Unlike some other moving companies, we value the trust our customers place in us. Our customer reviews on Google are genuine, and we never manipulate them. Every 5-star review is earned through hard work and exceptional service.
#
# Fully Insured
#
# Transit and public liability insurance on every move. Your goods are protected from loading to delivery.
#
# Genuine 5-Star Reviews
#
# 111 authentic Google reviews — never manipulated. Our reputation is built on real customer experiences.
#
# Transparent Pricing
#
# Hourly rates with no hidden fees. What you're quoted is what you pay — simple and straightforward.
#
# 5.0★
#
# Google Rating
#
# 111
#
# Verified Reviews
#
# Interstate Routes
#
# 24/7
#
# Available via Email
#
# Get a Free Quote
#
# Client Reviews
#
# Our Clients Say!
#
# Discover firsthand experiences from our valued clients. From seamless moves to exceptional service, our customers share how we made their relocation stress-free and rewarding.
#
# ★★★★★

# %%
from langchain_huggingface import HuggingFacePipeline

llm = HuggingFacePipeline.from_model_id(
    model_id="Qwen/Qwen2.5-0.5B-Instruct",
    task="text-generation",
    pipeline_kwargs={
        "max_new_tokens": 200,
        "temperature": 0.4,
        "do_sample": True,
    },
)
# Out:
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# c:\Users\arjun\Desktop\GenAI and LLM\rag_demo\venv\Lib\site-packages\huggingface_hub\file_download.py:142: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\arjun\.cache\huggingface\hub\models--Qwen--Qwen2.5-0.5B-Instruct. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  988MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'temperature', 'do_sample', 'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore = Chroma.from_documents(
    documents=docs,
    embedding=embeddings
)

retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 6}
)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough

system_prompt = (
    "You are an assistant for question-answering tasks. "
    "Use the following retrieved context to answer the question. "
    "If you don't know the answer, say you don't know. "
    "Keep the answer concise.\n\n"
    "Context:\n{context}"
)

prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("human", "{input}")
])

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

rag_chain = (
    {
        "context": retriever | format_docs,
        "input": RunnablePassthrough()
    }
    | prompt
    | llm
)

response = rag_chain.invoke(
    "What kind of services they provide?"
)

print(response)
# Out:
# [transformers] Both `max_new_tokens` (=200) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer Qwen2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# System: You are an assistant for question-answering tasks. Use the following retrieved context to answer the question. If you don't know the answer, say you don't know. Keep the answer concise.
#
# Context:
# Unlike some other moving companies, we value the trust our customers place in us. Our customer reviews on Google are genuine, and we never manipulate them. Every 5-star review is earned through hard work and exceptional service.
#
# Fully Insured
#
# Transit and public liability insurance on every move. Your goods are protected from loading to delivery.
#
# Genuine 5-Star Reviews
#
# 111 authentic Google reviews — never manipulated. Our reputation is built on real customer experiences.
#
# Transparent Pricing
#
# Hourly rates with no hidden fees. What you're quoted is what you pay — simple and straightforward.
#
# 5.0★
#
# Google Rating
#
# 111
#
# Verified Reviews
#
# Interstate Routes
#
# 24/7
#
# Available via Email
#
# Get a Free Quote
#
# Client Reviews
#
# Our Clients Say!
#
# Discover firsthand experiences from our valued clients. From seamless moves to exceptional service, our customers share how we made their relocation stress-free and rewarding.
#
# ★★★★★
#
# Unlike some other moving companies, we value the trust our customers place in us. Our customer reviews on Google are genuine, and we never manipulate them. Every 5-star review is earned through hard work and exceptional service.
#
# Fully Insured
#
# Transit and public liability insurance on every move. Your goods are protected from loading to delivery.
#
# Genuine 5-Star Reviews
#
# 111 authentic Google reviews — never manipulated. Our reputation is built on real customer experiences.
#
# Transparent Pricing
#
# Hourly rates with no hidden fees. What you're quoted is what you pay — simple and straightforward.
#
# 5.0★
#
# Google Rating
#
# 111
#
# Verified Reviews
#
# Interstate Routes
#
# 24/7
#
# Available via Email
#
# Get a Free Quote
#
# Client Reviews
#
# Our Clients Say!
#
# Discover firsthand experiences from our valued clients. From seamless moves to exceptional service, our customers share how we made their relocation stress-free and rewarding.
#
# ★★★★★
#
# Local Removalists Melbourne
#
# Top-notch local moving services tailored to your needs — from studio apartments to large family homes.
#
# What We Do
#
# Comprehensive Local Moving Services
#
# We offer a full range of local moving services for Melbourne residents and businesses. Our experienced team handles every move with care and professionalism.
#
# Apartment Moving
#
# Efficient and careful relocation services tailored for apartments of all sizes. We navigate lifts, stairs, and narrow corridors with ease.
#
# Villa Moving
#
# Comprehensive moving solutions for large residences and villas. We handle your valuable possessions with the utmost care and attention.
#
# Household Moving
#
# Full-service moving options for households of every size, including packing, loading, transportation, and unpacking at your new home.
#
# Office Moving
#
# Specialised expertise in office relocations. We minimise downtime and ensure your business is up and running as quickly as possible.
#
# Furniture Moving
#
# Local Removalists Melbourne
#
# Top-notch local moving services tailored to your needs — from studio apartments to large family homes.
#
# What We Do
#
# Comprehensive Local Moving Services
#
# We offer a full range of local moving services for Melbourne residents and businesses. Our experienced team handles every move with care and professionalism.
#
# Apartment Moving
#
# Efficient and careful relocation services tailored for apartments of all sizes. We navigate lifts, stairs, and narrow corridors with ease.
#
# Villa Moving
#
# Comprehensive moving solutions for large residences and villas. We handle your valuable possessions with the utmost care and attention.
#
# Household Moving
#
# Full-service moving options for households of every size, including packing, loading, transportation, and unpacking at your new home.
#
# Office Moving
#
# Specialised expertise in office relocations. We minimise downtime and ensure your business is up and running as quickly as possible.
#
# Furniture Moving
#
# Packing Services
#
# Optional packing and unpacking services using quality materials to ensure your items arrive safely at their destination.
#
# Home Removals
#
# Full-service home moving from 1-bedroom apartments to large 5-bedroom properties. We tailor every move to your specific needs.
#
# Interstate Moves
#
# Reliable interstate removalist services from Melbourne to Sydney, Brisbane, Adelaide, and Canberra with transparent pricing.
#
# Home Packages
#
# Moving Packages by Home Size
#
# Choose the package that best fits your home. Not sure? Call us and we'll help you decide.
#
# 1 Bedroom Home
#
# Small Truck from $125/hr
#
# 1 Bed & Mattress
#
# Tall Boy
#
# Bedside Table
#
# Refrigerator
#
# Washing Machine
#
# Some Boxes
#
# 2 Bedroom Home
#
# Medium Truck from $140/hr
#
# 2 Beds & Mattresses
#
# Tall Boy & Bedside Tables
#
# Refrigerator
#
# Washing Machine
#
# Dresser
#
# Barbeque
#
# Boxes & Loose Stuff
#
# Large Home (4–5 Bed)
#
# Large or X-Large Truck
#
# 4–5 Bedrooms
#
# Double Lounge
#
# All Beds & Mattresses
#
# Tall Boy & Bedside Tables
#
# Packing Services
#
# Optional packing and unpacking services using quality materials to ensure your items arrive safely at their destination.
#
# Home Removals
#
# Full-service home moving from 1-bedroom apartments to large 5-bedroom properties. We tailor every move to your specific needs.
#
# Interstate Moves
#
# Reliable interstate removalist services from Melbourne to Sydney, Brisbane, Adelaide, and Canberra with transparent pricing.
#
# Home Packages
#
# Moving Packages by Home Size
#
# Choose the package that best fits your home. Not sure? Call us and we'll help you decide.
#
# 1 Bedroom Home
#
# Small Truck from $125/hr
#
# 1 Bed & Mattress
#
# Tall Boy
#
# Bedside Table
#
# Refrigerator
#
# Washing Machine
#
# Some Boxes
#
# 2 Bedroom Home
#
# Medium Truck from $140/hr
#
# 2 Beds & Mattresses
#
# Tall Boy & Bedside Tables
#
# Refrigerator
#
# Washing Machine
#
# Dresser
#
# Barbeque
#
# Boxes & Loose Stuff
#
# Large Home (4–5 Bed)
#
# Large or X-Large Truck
#
# 4–5 Bedrooms
#
# Double Lounge
#
# All Beds & Mattresses
#
# Tall Boy & Bedside Tables
# Human: What kind of services they provide? The human response provides information about the types of local moving services offered by the company. It mentions "Comprehensive Local Moving Services" which indicates that the company offers various types of moving services tailored to different needs. The text also states that these services include apartment moving, villa moving, household moving, office moving, furniture moving, and home removals. Additionally, it notes that the company offers packing and unpacking services using quality materials to ensure safe delivery. Finally, it lists several packages such as small truck, medium truck, large truck, and home-sized packages for larger homes. Overall, this response describes the range of services provided by the company based on its offerings.
